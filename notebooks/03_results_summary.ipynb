# %% [markdown]
# # 03 — Reanalysis results summary
# Loads the full-run outputs already supplied in this package. These results remain provisional until the unique-worker identity issue is resolved.

# %%
from pathlib import Path
import pandas as pd
ROOT=Path('..').resolve()
primary=pd.read_csv(ROOT/'results/primary/model_summary_primary.csv')
ablation=pd.read_csv(ROOT/'results/primary/feature_ablation_summary.csv')
paired=pd.read_csv(ROOT/'results/primary/paired_mcnemar_holm.csv')
sex=pd.read_csv(ROOT/'results/secondary/sex_stratified_summary.csv')
sensitivity=pd.read_csv(ROOT/'results/secondary/sensitivity_summary.csv')

# %%
primary[['model','balanced_accuracy_mean','macro_f1_mean','mcc_mean','accuracy_mean']].sort_values('balanced_accuracy_mean',ascending=False)

# %%
ablation[['model','feature_set','balanced_accuracy_mean','macro_f1_mean','mcc_mean']].sort_values('balanced_accuracy_mean',ascending=False)

# %%
paired

# %%
sex

# %%
sensitivity
